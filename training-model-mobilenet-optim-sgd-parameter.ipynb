# %% [markdown]
# Setup awal

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import AdamW
from torch.utils.data import DataLoader, random_split, Subset
from torchvision import datasets, transforms, models
from sklearn.model_selection import KFold
import numpy as np
import os
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# Transformasi gambar

# %%
from torchvision import datasets, transforms

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

data_dir = "/kaggle/input/datasetta2/Multi-Class Driver Behavior Image Dataset"
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
print("Jumlah total data:", len(dataset))
print("Kelas:", dataset.classes)
# Out:
# Jumlah total data: 7276
# Kelas: ['other_activities', 'safe_driving', 'talking_phone', 'texting_phone', 'turning']

# %% [markdown]
# Splitting dataset

# %%
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(
    dataset, [train_size, val_size, test_size],
    generator=torch.Generator().manual_seed(42)
)

print(len(train_dataset), len(val_dataset), len(test_dataset))
# Out:
# 5820 727 729

# %% [markdown]
# Setup k-fold=5

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# %% [markdown]
# Definisikan fungsi training dan validation

# %%
def train_one_epoch(model, dataloader, criterion, optimizer):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct / total
    print(f"  🔹Train Loss: {epoch_loss:.4f} | Train Acc: {epoch_acc:.4f}")
    return epoch_loss, epoch_acc
    
def validate(model, dataloader, criterion):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for batch_idx, (inputs, labels) in enumerate(dataloader):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct / total
    print(f"  🔸Val Loss: {epoch_loss:.4f} | Val Acc: {epoch_acc:.4f}")
    return epoch_loss, epoch_acc

# %%
num_classes = len(dataset.classes)
print("num_classes =", num_classes)
# Out:
# num_classes = 5

# %% [markdown]
# Training model mobilenet menggunakan data train

# %%
import time
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.utils.data import DataLoader, Subset
from torchvision import models
import numpy as np
import pandas as pd  
import os

# === Hyperparameters ===
num_classes = len(dataset.classes)
batch_size = 32
epochs = 15
learning_rate = 1e-4
weight_decay = 1e-2
k_folds = 5

# Folder untuk menyimpan hasil training
base_dir = "/kaggle/working"
os.makedirs(f"{base_dir}/training_logs", exist_ok=True)
os.makedirs(f"{base_dir}/saved_models", exist_ok=True)

fold_results = {}

for fold, (train_idx, val_idx) in enumerate(kfold.split(np.arange(len(train_dataset)))):
    print(f"\n========== Fold {fold+1}/{k_folds} ==========")
    fold_log = []

    # Subset data untuk fold ini
    train_subsampler = Subset(train_dataset, train_idx)
    val_subsampler = Subset(train_dataset, val_idx)

    train_loader = DataLoader(train_subsampler, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_subsampler, batch_size=batch_size, shuffle=False, num_workers=2)

    # Load pretrained MobileNetV2
    model = models.mobilenet_v2(weights='IMAGENET1K_V1')
    model.classifier[1] = nn.Linear(model.last_channel, num_classes)
    model = model.to(device)

    # Loss dan optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(
    model.parameters(),
    lr=learning_rate,
    momentum=0.9,
    weight_decay=weight_decay
    )

    best_acc = 0.0
    fold_start_time = time.time()

    # === DataFrame untuk menyimpan log tiap epoch ===
    log_data = {
        "epoch": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": [],
        "epoch_time_sec": []
    }

    for epoch in range(epochs):
        epoch_start = time.time()
        print(f"\nEpoch {epoch+1}/{epochs}")

        # Training & Validation
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer)
        val_loss, val_acc = validate(model, val_loader, criterion)

        epoch_end = time.time()
        epoch_time = epoch_end - epoch_start

        # Print progress
        print(f"Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f}")
        print(f"Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f}")
        print(f"⏱️ Waktu Epoch {epoch+1}: {epoch_time/60:.2f} menit")

        # Simpan log ke dictionary
        log_data["epoch"].append(epoch + 1)
        log_data["train_loss"].append(train_loss)
        log_data["train_acc"].append(train_acc)
        log_data["val_loss"].append(val_loss)
        log_data["val_acc"].append(val_acc)
        log_data["epoch_time_sec"].append(epoch_time)

        # Simpan model terbaik per fold
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), f"{base_dir}/saved_models/best_model_fold{fold+1}.pth")

    # Penyimpanan hasil log (pakai log_data)
    with open(f"{base_dir}/training_logs/fold{fold+1}_log.txt", "w") as f:
        for i in range(len(log_data["epoch"])):
            f.write(
                f"Epoch {log_data['epoch'][i]}: "
                f"Train Loss={log_data['train_loss'][i]:.4f}, Acc={log_data['train_acc'][i]:.4f}, "
                f"Val Loss={log_data['val_loss'][i]:.4f}, Acc={log_data['val_acc'][i]:.4f}, "
                f"Time={log_data['epoch_time_sec'][i]:.2f}s\n"
            )

    # Simpan hasil log ke CSV
    df_log = pd.DataFrame(log_data)
    df_log.to_csv(f"{base_dir}/training_logs/training_log_fold{fold+1}.csv", index=False)
    print(f"📁 Log training fold {fold+1} disimpan ke training_logs/training_log_fold{fold+1}.csv")

    # Catat hasil terbaik fold ini
    fold_end_time = time.time()
    fold_time = fold_end_time - fold_start_time
    fold_results[fold] = {
        "best_acc": best_acc,
        "fold_time": fold_time
    }

    print(f"\n✅ Best Val Acc for fold {fold+1}: {best_acc:.4f}")
    print(f"🕒 Total waktu training Fold {fold+1}: {fold_time/60:.2f} menit")

# Rekap hasil akhir
print("\n========== K-Fold Cross Validation Results ==========")
for k, v in fold_results.items():
    print(f"Fold {k+1}: Acc={v['best_acc']:.4f} | Waktu={v['fold_time']/60:.2f} menit")

avg_acc = np.mean([v['best_acc'] for v in fold_results.values()])
total_time = np.sum([v['fold_time'] for v in fold_results.values()])

print(f"\n📊 Rata-rata Akurasi: {avg_acc:.4f}")
print(f"🕒 Total Waktu Training (semua fold): {total_time/60:.2f} menit")
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# ========== Fold 1/5 ==========
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 120MB/s]
# Epoch 1/15
#   🔹Train Loss: 1.5615 | Train Acc: 0.2947
#   🔸Val Loss: 1.4287 | Val Acc: 0.4794
# Train Loss: 1.5615 | Acc: 0.2947
# Val   Loss: 1.4287 | Acc: 0.4794
# ⏱️ Waktu Epoch 1: 1.29 menit
#
# Epoch 2/15
#   🔹Train Loss: 1.3295 | Train Acc: 0.5500
#   🔸Val Loss: 1.1994 | Val Acc: 0.6607
# Train Loss: 1.3295 | Acc: 0.5500
# Val   Loss: 1.1994 | Acc: 0.6607
# ⏱️ Waktu Epoch 2: 0.97 menit
#
# Epoch 3/15
#   🔹Train Loss: 1.0982 | Train Acc: 0.6828
#   🔸Val Loss: 0.9566 | Val Acc: 0.7311
# Train Loss: 1.0982 | Acc: 0.6828
# Val   Loss: 0.9566 | Acc: 0.7311
# ⏱️ Waktu Epoch 3: 0.99 menit
#
# Epoch 4/15
#   🔹Train Loss: 0.8661 | Train Acc: 0.7674
#   🔸Val Loss: 0.7389 | Val Acc: 0.8101
# Train Loss: 0.8661 | Acc: 0.7674
# Val   Loss: 0.7389 | Acc: 0.8101
# ⏱️ Waktu Epoch 4: 1.01 menit
#
# Epoch 5/15
#   🔹Train Loss: 0.6777 | Train Acc: 0.8200
#   🔸Val Loss: 0.5726 | Val Acc: 0.8531
# Train Loss: 0.6777 | Acc: 0.8200
# Val   Loss: 0.5726 | Acc: 0.8531
# ⏱️ Waktu Epoch 5: 0.98 menit
#
# Epoch 6/15
#   🔹Train Loss: 0.5370 | Train Acc: 0.8595
#   🔸Val Loss: 0.4628 | Val Acc: 0.8711
# Train Loss: 0.5370 | Acc: 0.8595
# Val   Loss: 0.4628 | Acc: 0.8711
# ⏱️ Waktu Epoch 6: 1.04 menit
#
# Epoch 7/15
#   🔹Train Loss: 0.4432 | Train Acc: 0.8808
#   🔸Val Loss: 0.3851 | Val Acc: 0.8849
# Train Loss: 0.4432 | Acc: 0.8808
# Val   Loss: 0.3851 | Acc: 0.8849
# ⏱️ Waktu Epoch 7: 1.01 menit
#
# Epoch 8/15
#   🔹Train Loss: 0.3799 | Train Acc: 0.8941
#   🔸Val Loss: 0.3363 | Val Acc: 0.8969
# Train Loss: 0.3799 | Acc: 0.8941
# Val   Loss: 0.3363 | Acc: 0.8969
# ⏱️ Waktu Epoch 8: 1.01 menit
#
# Epoch 9/15
#   🔹Train Loss: 0.3253 | Train Acc: 0.9057
#   🔸Val Loss: 0.3030 | Val Acc: 0.9055
# Train Loss: 0.3253 | Acc: 0.9057
# Val   Loss: 0.3030 | Acc: 0.9055
# ⏱️ Waktu Epoch 9: 0.97 menit
#
# Epoch 10/15
#   🔹Train Loss: 0.2954 | Train Acc: 0.9158
#   🔸Val Loss: 0.2725 | Val Acc: 0.9089
# Train Loss: 0.2954 | Acc: 0.9158
# Val   Loss: 0.2725 | Acc: 0.9089
# ⏱️ Waktu Epoch 10: 1.00 menit
#
# Epoch 11/15
#   🔹Train Loss: 0.2588 | Train Acc: 0.9244
#   🔸Val Loss: 0.2509 | Val Acc: 0.9149
# Train Loss: 0.2588 | Acc: 0.9244
# Val   Loss: 0.2509 | Acc: 0.9149
# ⏱️ Waktu Epoch 11: 1.00 menit
#
# Epoch 12/15
#   🔹Train Loss: 0.2316 | Train Acc: 0.9341
#   🔸Val Loss: 0.2362 | Val Acc: 0.9175
# Train Loss: 0.2316 | Acc: 0.9341
# Val   Loss: 0.2362 | Acc: 0.9175
# ⏱️ Waktu Epoch 12: 1.00 menit
#
# Epoch 13/15
#   🔹Train Loss: 0.2108 | Train Acc: 0.9409
#   🔸Val Loss: 0.2230 | Val Acc: 0.9227
# Train Loss: 0.2108 | Acc: 0.9409
# Val   Loss: 0.2230 | Acc: 0.9227
# ⏱️ Waktu Epoch 13: 1.00 menit
#
# Epoch 14/15
#   🔹Train Loss: 0.1961 | Train Acc: 0.9446
#   🔸Val Loss: 0.2157 | Val Acc: 0.9227
# Train Loss: 0.1961 | Acc: 0.9446
# Val   Loss: 0.2157 | Acc: 0.9227
# ⏱️ Waktu Epoch 14: 1.02 menit
#
# Epoch 15/15
#   🔹Train Loss: 0.1782 | Train Acc: 0.9452
#   🔸Val Loss: 0.1998 | Val Acc: 0.9287
# Train Loss: 0.1782 | Acc: 0.9452
# Val   Loss: 0.1998 | Acc: 0.9287
# ⏱️ Waktu Epoch 15: 0.96 menit
# 📁 Log training fold 1 disimpan ke training_logs/training_log_fold1.csv
#
# ✅ Best Val Acc for fold 1: 0.9287
# 🕒 Total waktu training Fold 1: 15.26 menit
#
# ========== Fold 2/5 ==========
#
# Epoch 1/15
#   🔹Train Loss: 1.5470 | Train Acc: 0.3342
#   🔸Val Loss: 1.4009 | Val Acc: 0.5584
# Train Loss: 1.5470 | Acc: 0.3342
# Val   Loss: 1.4009 | Acc: 0.5584
# ⏱️ Waktu Epoch 1: 0.99 menit
#
# Epoch 2/15
#   🔹Train Loss: 1.3076 | Train Acc: 0.5874
#   🔸Val Loss: 1.1611 | Val Acc: 0.6804
# Train Loss: 1.3076 | Acc: 0.5874
# Val   Loss: 1.1611 | Acc: 0.6804
# ⏱️ Waktu Epoch 2: 0.98 menit
#
# Epoch 3/15
#   🔹Train Loss: 1.0588 | Train Acc: 0.7118
#   🔸Val Loss: 0.9209 | Val Acc: 0.7526
# Train Loss: 1.0588 | Acc: 0.7118
# Val   Loss: 0.9209 | Acc: 0.7526
# ⏱️ Waktu Epoch 3: 0.98 menit
#
# Epoch 4/15
#   🔹Train Loss: 0.8330 | Train Acc: 0.7771
#   🔸Val Loss: 0.7185 | Val Acc: 0.7964
# Train Loss: 0.8330 | Acc: 0.7771
# Val   Loss: 0.7185 | Acc: 0.7964
# ⏱️ Waktu Epoch 4: 0.98 menit
#
# Epoch 5/15
#   🔹Train Loss: 0.6424 | Train Acc: 0.8243
#   🔸Val Loss: 0.5733 | Val Acc: 0.8436
# Train Loss: 0.6424 | Acc: 0.8243
# Val   Loss: 0.5733 | Acc: 0.8436
# ⏱️ Waktu Epoch 5: 0.98 menit
#
# Epoch 6/15
#   🔹Train Loss: 0.5227 | Train Acc: 0.8559
#   🔸Val Loss: 0.4770 | Val Acc: 0.8651
# Train Loss: 0.5227 | Acc: 0.8559
# Val   Loss: 0.4770 | Acc: 0.8651
# ⏱️ Waktu Epoch 6: 0.99 menit
#
# Epoch 7/15
#   🔹Train Loss: 0.4308 | Train Acc: 0.8774
#   🔸Val Loss: 0.4092 | Val Acc: 0.8832
# Train Loss: 0.4308 | Acc: 0.8774
# Val   Loss: 0.4092 | Acc: 0.8832
# ⏱️ Waktu Epoch 7: 0.96 menit
#
# Epoch 8/15
#   🔹Train Loss: 0.3740 | Train Acc: 0.8941
#   🔸Val Loss: 0.3639 | Val Acc: 0.8883
# Train Loss: 0.3740 | Acc: 0.8941
# Val   Loss: 0.3639 | Acc: 0.8883
# ⏱️ Waktu Epoch 8: 0.97 menit
#
# Epoch 9/15
#   🔹Train Loss: 0.3249 | Train Acc: 0.9094
#   🔸Val Loss: 0.3255 | Val Acc: 0.9003
# Train Loss: 0.3249 | Acc: 0.9094
# Val   Loss: 0.3255 | Acc: 0.9003
# ⏱️ Waktu Epoch 9: 1.00 menit
#
# Epoch 10/15
#   🔹Train Loss: 0.2835 | Train Acc: 0.9190
#   🔸Val Loss: 0.2979 | Val Acc: 0.9038
# Train Loss: 0.2835 | Acc: 0.9190
# Val   Loss: 0.2979 | Acc: 0.9038
# ⏱️ Waktu Epoch 10: 0.98 menit
#
# Epoch 11/15
#   🔹Train Loss: 0.2562 | Train Acc: 0.9276
#   🔸Val Loss: 0.2726 | Val Acc: 0.9107
# Train Loss: 0.2562 | Acc: 0.9276
# Val   Loss: 0.2726 | Acc: 0.9107
# ⏱️ Waktu Epoch 11: 1.02 menit
#
# Epoch 12/15
#   🔹Train Loss: 0.2378 | Train Acc: 0.9285
#   🔸Val Loss: 0.2542 | Val Acc: 0.9124
# Train Loss: 0.2378 | Acc: 0.9285
# Val   Loss: 0.2542 | Acc: 0.9124
# ⏱️ Waktu Epoch 12: 0.97 menit
#
# Epoch 13/15
#   🔹Train Loss: 0.2170 | Train Acc: 0.9349
#   🔸Val Loss: 0.2437 | Val Acc: 0.9124
# Train Loss: 0.2170 | Acc: 0.9349
# Val   Loss: 0.2437 | Acc: 0.9124
# ⏱️ Waktu Epoch 13: 1.00 menit
#
# Epoch 14/15
#   🔹Train Loss: 0.1956 | Train Acc: 0.9414
#   🔸Val Loss: 0.2265 | Val Acc: 0.9192
# Train Loss: 0.1956 | Acc: 0.9414
# Val   Loss: 0.2265 | Acc: 0.9192
# ⏱️ Waktu Epoch 14: 0.98 menit
#
# Epoch 15/15
#   🔹Train Loss: 0.1797 | Train Acc: 0.9474
#   🔸Val Loss: 0.2158 | Val Acc: 0.9261
# Train Loss: 0.1797 | Acc: 0.9474
# Val   Loss: 0.2158 | Acc: 0.9261
# ⏱️ Waktu Epoch 15: 0.95 menit
# 📁 Log training fold 2 disimpan ke training_logs/training_log_fold2.csv
#
# ✅ Best Val Acc for fold 2: 0.9261
# 🕒 Total waktu training Fold 2: 14.72 menit
#
# ========== Fold 3/5 ==========
#
# Epoch 1/15
#   🔹Train Loss: 1.5543 | Train Acc: 0.3136
#   🔸Val Loss: 1.4197 | Val Acc: 0.5017
# Train Loss: 1.5543 | Acc: 0.3136
# Val   Loss: 1.4197 | Acc: 0.5017
# ⏱️ Waktu Epoch 1: 0.99 menit
#
# Epoch 2/15
#   🔹Train Loss: 1.3199 | Train Acc: 0.5550
#   🔸Val Loss: 1.1882 | Val Acc: 0.6847
# Train Loss: 1.3199 | Acc: 0.5550
# Val   Loss: 1.1882 | Acc: 0.6847
# ⏱️ Waktu Epoch 2: 0.99 menit
#
# Epoch 3/15
#   🔹Train Loss: 1.0897 | Train Acc: 0.6873
#   🔸Val Loss: 0.9664 | Val Acc: 0.7534
# Train Loss: 1.0897 | Acc: 0.6873
# Val   Loss: 0.9664 | Acc: 0.7534
# ⏱️ Waktu Epoch 3: 0.99 menit
#
# Epoch 4/15
#   🔹Train Loss: 0.8849 | Train Acc: 0.7627
#   🔸Val Loss: 0.7754 | Val Acc: 0.7981
# Train Loss: 0.8849 | Acc: 0.7627
# Val   Loss: 0.7754 | Acc: 0.7981
# ⏱️ Waktu Epoch 4: 0.99 menit
#
# Epoch 5/15
#   🔹Train Loss: 0.7092 | Train Acc: 0.8183
#   🔸Val Loss: 0.6214 | Val Acc: 0.8333
# Train Loss: 0.7092 | Acc: 0.8183
# Val   Loss: 0.6214 | Acc: 0.8333
# ⏱️ Waktu Epoch 5: 0.99 menit
#
# Epoch 6/15
#   🔹Train Loss: 0.5665 | Train Acc: 0.8514
#   🔸Val Loss: 0.5084 | Val Acc: 0.8514
# Train Loss: 0.5665 | Acc: 0.8514
# Val   Loss: 0.5084 | Acc: 0.8514
# ⏱️ Waktu Epoch 6: 0.98 menit
#
# Epoch 7/15
#   🔹Train Loss: 0.4647 | Train Acc: 0.8793
#   🔸Val Loss: 0.4321 | Val Acc: 0.8823
# Train Loss: 0.4647 | Acc: 0.8793
# Val   Loss: 0.4321 | Acc: 0.8823
# ⏱️ Waktu Epoch 7: 0.97 menit
#
# Epoch 8/15
#   🔹Train Loss: 0.3954 | Train Acc: 0.8898
#   🔸Val Loss: 0.3746 | Val Acc: 0.8857
# Train Loss: 0.3954 | Acc: 0.8898
# Val   Loss: 0.3746 | Acc: 0.8857
# ⏱️ Waktu Epoch 8: 0.99 menit
#
# Epoch 9/15
#   🔹Train Loss: 0.3417 | Train Acc: 0.9072
#   🔸Val Loss: 0.3361 | Val Acc: 0.9012
# Train Loss: 0.3417 | Acc: 0.9072
# Val   Loss: 0.3361 | Acc: 0.9012
# ⏱️ Waktu Epoch 9: 1.00 menit
#
# Epoch 10/15
#   🔹Train Loss: 0.2959 | Train Acc: 0.9126
#   🔸Val Loss: 0.3039 | Val Acc: 0.9021
# Train Loss: 0.2959 | Acc: 0.9126
# Val   Loss: 0.3039 | Acc: 0.9021
# ⏱️ Waktu Epoch 10: 1.02 menit
#
# Epoch 11/15
#   🔹Train Loss: 0.2685 | Train Acc: 0.9238
#   🔸Val Loss: 0.2793 | Val Acc: 0.9107
# Train Loss: 0.2685 | Acc: 0.9238
# Val   Loss: 0.2793 | Acc: 0.9107
# ⏱️ Waktu Epoch 11: 0.99 menit
#
# Epoch 12/15
#   🔹Train Loss: 0.2377 | Train Acc: 0.9338
#   🔸Val Loss: 0.2605 | Val Acc: 0.9132
# Train Loss: 0.2377 | Acc: 0.9338
# Val   Loss: 0.2605 | Acc: 0.9132
# ⏱️ Waktu Epoch 12: 1.03 menit
#
# Epoch 13/15
#   🔹Train Loss: 0.2102 | Train Acc: 0.9386
#   🔸Val Loss: 0.2453 | Val Acc: 0.9149
# Train Loss: 0.2102 | Acc: 0.9386
# Val   Loss: 0.2453 | Acc: 0.9149
# ⏱️ Waktu Epoch 13: 1.02 menit
#
# Epoch 14/15
#   🔹Train Loss: 0.1896 | Train Acc: 0.9454
#   🔸Val Loss: 0.2353 | Val Acc: 0.9175
# Train Loss: 0.1896 | Acc: 0.9454
# Val   Loss: 0.2353 | Acc: 0.9175
# ⏱️ Waktu Epoch 14: 0.99 menit
#
# Epoch 15/15
#   🔹Train Loss: 0.1779 | Train Acc: 0.9508
#   🔸Val Loss: 0.2269 | Val Acc: 0.9167
# Train Loss: 0.1779 | Acc: 0.9508
# Val   Loss: 0.2269 | Acc: 0.9167
# ⏱️ Waktu Epoch 15: 1.01 menit
# 📁 Log training fold 3 disimpan ke training_logs/training_log_fold3.csv
#
# ✅ Best Val Acc for fold 3: 0.9175
# 🕒 Total waktu training Fold 3: 14.97 menit
#
# ========== Fold 4/5 ==========
#
# Epoch 1/15
#   🔹Train Loss: 1.5484 | Train Acc: 0.3237
#   🔸Val Loss: 1.4124 | Val Acc: 0.5722
# Train Loss: 1.5484 | Acc: 0.3237
# Val   Loss: 1.4124 | Acc: 0.5722
# ⏱️ Waktu Epoch 1: 1.00 menit
#
# Epoch 2/15
#   🔹Train Loss: 1.3183 | Train Acc: 0.5717
#   🔸Val Loss: 1.1828 | Val Acc: 0.6856
# Train Loss: 1.3183 | Acc: 0.5717
# Val   Loss: 1.1828 | Acc: 0.6856
# ⏱️ Waktu Epoch 2: 0.99 menit
#
# Epoch 3/15
#   🔹Train Loss: 1.0706 | Train Acc: 0.7012
#   🔸Val Loss: 0.9357 | Val Acc: 0.7595
# Train Loss: 1.0706 | Acc: 0.7012
# Val   Loss: 0.9357 | Acc: 0.7595
# ⏱️ Waktu Epoch 3: 1.04 menit
#
# Epoch 4/15
#   🔹Train Loss: 0.8401 | Train Acc: 0.7741
#   🔸Val Loss: 0.7231 | Val Acc: 0.7998
# Train Loss: 0.8401 | Acc: 0.7741
# Val   Loss: 0.7231 | Acc: 0.7998
# ⏱️ Waktu Epoch 4: 0.98 menit
#
# Epoch 5/15
#   🔹Train Loss: 0.6497 | Train Acc: 0.8265
#   🔸Val Loss: 0.5669 | Val Acc: 0.8368
# Train Loss: 0.6497 | Acc: 0.8265
# Val   Loss: 0.5669 | Acc: 0.8368
# ⏱️ Waktu Epoch 5: 1.03 menit
#
# Epoch 6/15
#   🔹Train Loss: 0.5135 | Train Acc: 0.8655
#   🔸Val Loss: 0.4748 | Val Acc: 0.8591
# Train Loss: 0.5135 | Acc: 0.8655
# Val   Loss: 0.4748 | Acc: 0.8591
# ⏱️ Waktu Epoch 6: 0.98 menit
#
# Epoch 7/15
#   🔹Train Loss: 0.4302 | Train Acc: 0.8791
#   🔸Val Loss: 0.4110 | Val Acc: 0.8866
# Train Loss: 0.4302 | Acc: 0.8791
# Val   Loss: 0.4110 | Acc: 0.8866
# ⏱️ Waktu Epoch 7: 1.00 menit
#
# Epoch 8/15
#   🔹Train Loss: 0.3689 | Train Acc: 0.8965
#   🔸Val Loss: 0.3659 | Val Acc: 0.8918
# Train Loss: 0.3689 | Acc: 0.8965
# Val   Loss: 0.3659 | Acc: 0.8918
# ⏱️ Waktu Epoch 8: 1.01 menit
#
# Epoch 9/15
#   🔹Train Loss: 0.3189 | Train Acc: 0.9122
#   🔸Val Loss: 0.3334 | Val Acc: 0.9012
# Train Loss: 0.3189 | Acc: 0.9122
# Val   Loss: 0.3334 | Acc: 0.9012
# ⏱️ Waktu Epoch 9: 0.97 menit
#
# Epoch 10/15
#   🔹Train Loss: 0.2792 | Train Acc: 0.9188
#   🔸Val Loss: 0.3064 | Val Acc: 0.9021
# Train Loss: 0.2792 | Acc: 0.9188
# Val   Loss: 0.3064 | Acc: 0.9021
# ⏱️ Waktu Epoch 10: 1.02 menit
#
# Epoch 11/15
#   🔹Train Loss: 0.2511 | Train Acc: 0.9308
#   🔸Val Loss: 0.2879 | Val Acc: 0.9055
# Train Loss: 0.2511 | Acc: 0.9308
# Val   Loss: 0.2879 | Acc: 0.9055
# ⏱️ Waktu Epoch 11: 1.02 menit
#
# Epoch 12/15
#   🔹Train Loss: 0.2277 | Train Acc: 0.9360
#   🔸Val Loss: 0.2707 | Val Acc: 0.9072
# Train Loss: 0.2277 | Acc: 0.9360
# Val   Loss: 0.2707 | Acc: 0.9072
# ⏱️ Waktu Epoch 12: 1.02 menit
#
# Epoch 13/15
#   🔹Train Loss: 0.2096 | Train Acc: 0.9386
#   🔸Val Loss: 0.2568 | Val Acc: 0.9149
# Train Loss: 0.2096 | Acc: 0.9386
# Val   Loss: 0.2568 | Acc: 0.9149
# ⏱️ Waktu Epoch 13: 1.00 menit
#
# Epoch 14/15
#   🔹Train Loss: 0.1907 | Train Acc: 0.9465
#   🔸Val Loss: 0.2463 | Val Acc: 0.9184
# Train Loss: 0.1907 | Acc: 0.9465
# Val   Loss: 0.2463 | Acc: 0.9184
# ⏱️ Waktu Epoch 14: 1.01 menit
#
# Epoch 15/15
#   🔹Train Loss: 0.1741 | Train Acc: 0.9534
#   🔸Val Loss: 0.2405 | Val Acc: 0.9192
# Train Loss: 0.1741 | Acc: 0.9534
# Val   Loss: 0.2405 | Acc: 0.9192
# ⏱️ Waktu Epoch 15: 1.01 menit
# 📁 Log training fold 4 disimpan ke training_logs/training_log_fold4.csv
#
# ✅ Best Val Acc for fold 4: 0.9192
# 🕒 Total waktu training Fold 4: 15.09 menit
#
# ========== Fold 5/5 ==========
#
# Epoch 1/15
#   🔹Train Loss: 1.5096 | Train Acc: 0.3707
#   🔸Val Loss: 1.3929 | Val Acc: 0.5249
# Train Loss: 1.5096 | Acc: 0.3707
# Val   Loss: 1.3929 | Acc: 0.5249
# ⏱️ Waktu Epoch 1: 1.00 menit
#
# Epoch 2/15
#   🔹Train Loss: 1.2830 | Train Acc: 0.5874
#   🔸Val Loss: 1.1653 | Val Acc: 0.6400
# Train Loss: 1.2830 | Acc: 0.5874
# Val   Loss: 1.1653 | Acc: 0.6400
# ⏱️ Waktu Epoch 2: 1.02 menit
#
# Epoch 3/15
#   🔹Train Loss: 1.0573 | Train Acc: 0.6873
#   🔸Val Loss: 0.9459 | Val Acc: 0.7337
# Train Loss: 1.0573 | Acc: 0.6873
# Val   Loss: 0.9459 | Acc: 0.7337
# ⏱️ Waktu Epoch 3: 1.01 menit
#
# Epoch 4/15
#   🔹Train Loss: 0.8434 | Train Acc: 0.7663
#   🔸Val Loss: 0.7469 | Val Acc: 0.7930
# Train Loss: 0.8434 | Acc: 0.7663
# Val   Loss: 0.7469 | Acc: 0.7930
# ⏱️ Waktu Epoch 4: 0.99 menit
#
# Epoch 5/15
#   🔹Train Loss: 0.6646 | Train Acc: 0.8235
#   🔸Val Loss: 0.5920 | Val Acc: 0.8282
# Train Loss: 0.6646 | Acc: 0.8235
# Val   Loss: 0.5920 | Acc: 0.8282
# ⏱️ Waktu Epoch 5: 1.02 menit
#
# Epoch 6/15
#   🔹Train Loss: 0.5297 | Train Acc: 0.8589
#   🔸Val Loss: 0.4906 | Val Acc: 0.8582
# Train Loss: 0.5297 | Acc: 0.8589
# Val   Loss: 0.4906 | Acc: 0.8582
# ⏱️ Waktu Epoch 6: 0.99 menit
#
# Epoch 7/15
#   🔹Train Loss: 0.4477 | Train Acc: 0.8748
#   🔸Val Loss: 0.4202 | Val Acc: 0.8694
# Train Loss: 0.4477 | Acc: 0.8748
# Val   Loss: 0.4202 | Acc: 0.8694
# ⏱️ Waktu Epoch 7: 1.00 menit
#
# Epoch 8/15
#   🔹Train Loss: 0.3751 | Train Acc: 0.8995
#   🔸Val Loss: 0.3693 | Val Acc: 0.8789
# Train Loss: 0.3751 | Acc: 0.8995
# Val   Loss: 0.3693 | Acc: 0.8789
# ⏱️ Waktu Epoch 8: 1.04 menit
#
# Epoch 9/15
#   🔹Train Loss: 0.3358 | Train Acc: 0.9107
#   🔸Val Loss: 0.3314 | Val Acc: 0.8918
# Train Loss: 0.3358 | Acc: 0.9107
# Val   Loss: 0.3314 | Acc: 0.8918
# ⏱️ Waktu Epoch 9: 1.05 menit
#
# Epoch 10/15
#   🔹Train Loss: 0.2939 | Train Acc: 0.9156
#   🔸Val Loss: 0.3017 | Val Acc: 0.8995
# Train Loss: 0.2939 | Acc: 0.9156
# Val   Loss: 0.3017 | Acc: 0.8995
# ⏱️ Waktu Epoch 10: 1.03 menit
#
# Epoch 11/15
#   🔹Train Loss: 0.2585 | Train Acc: 0.9280
#   🔸Val Loss: 0.2814 | Val Acc: 0.9064
# Train Loss: 0.2585 | Acc: 0.9280
# Val   Loss: 0.2814 | Acc: 0.9064
# ⏱️ Waktu Epoch 11: 1.03 menit
#
# Epoch 12/15
#   🔹Train Loss: 0.2321 | Train Acc: 0.9343
#   🔸Val Loss: 0.2635 | Val Acc: 0.9107
# Train Loss: 0.2321 | Acc: 0.9343
# Val   Loss: 0.2635 | Acc: 0.9107
# ⏱️ Waktu Epoch 12: 1.02 menit
#
# Epoch 13/15
#   🔹Train Loss: 0.2110 | Train Acc: 0.9405
#   🔸Val Loss: 0.2507 | Val Acc: 0.9132
# Train Loss: 0.2110 | Acc: 0.9405
# Val   Loss: 0.2507 | Acc: 0.9132
# ⏱️ Waktu Epoch 13: 1.04 menit
#
# Epoch 14/15
#   🔹Train Loss: 0.1950 | Train Acc: 0.9452
#   🔸Val Loss: 0.2397 | Val Acc: 0.9115
# Train Loss: 0.1950 | Acc: 0.9452
# Val   Loss: 0.2397 | Acc: 0.9115
# ⏱️ Waktu Epoch 14: 1.06 menit
#
# Epoch 15/15
#   🔹Train Loss: 0.1814 | Train Acc: 0.9489
#   🔸Val Loss: 0.2285 | Val Acc: 0.9175
# Train Loss: 0.1814 | Acc: 0.9489
# Val   Loss: 0.2285 | Acc: 0.9175
# ⏱️ Waktu Epoch 15: 1.02 menit
# 📁 Log training fold 5 disimpan ke training_logs/training_log_fold5.csv
#
# ✅ Best Val Acc for fold 5: 0.9175
# 🕒 Total waktu training Fold 5: 15.33 menit
#
# ========== K-Fold Cross Validation Results ==========
# Fold 1: Acc=0.9287 | Waktu=15.26 menit
# Fold 2: Acc=0.9261 | Waktu=14.72 menit
# Fold 3: Acc=0.9175 | Waktu=14.97 menit
# Fold 4: Acc=0.9192 | Waktu=15.09 menit
# Fold 5: Acc=0.9175 | Waktu=15.33 menit
#
# 📊 Rata-rata Akurasi: 0.9218
# 🕒 Total Waktu Training (semua fold): 75.36 menit

# %% [markdown]
# Evaluasi rata-rata kfold

# %%
import numpy as np

print("\n=== HASIL K-FOLD CROSS VALIDATION ===")
for fold, acc in fold_results.items():
    print(f"Fold {fold+1}: {acc['best_acc']:.4f}")

mean_acc = np.mean([v['best_acc'] for v in fold_results.values()])
print(f"\nRata-rata akurasi K-Fold: {mean_acc:.4f}")
# Out:
# === HASIL K-FOLD CROSS VALIDATION ===
# Fold 1: 0.9287
# Fold 2: 0.9261
# Fold 3: 0.9175
# Fold 4: 0.9192
# Fold 5: 0.9175
#
# Rata-rata akurasi K-Fold: 0.9218

# %% [markdown]
# Final testing menggunakan data test

# %%
# Path lengkap model yang disimpan di cloud
model_path = "/kaggle/working/saved_models/best_model_fold1.pth"

# Load model terbaik
best_model = models.mobilenet_v2(weights='IMAGENET1K_V1')
best_model.classifier[1] = nn.Linear(best_model.last_channel, num_classes)
best_model.load_state_dict(torch.load(model_path, map_location=device))
best_model = best_model.to(device)
best_model.eval()

# Evaluasi di test set
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
test_loss, test_acc = validate(best_model, test_loader, criterion)

print(f"\nEvaluasi di TEST SET (10%):")
print(f"Loss: {test_loss:.4f} | Akurasi: {test_acc:.4f}")
# Out:
#   🔸Val Loss: 0.2560 | Val Acc: 0.8985
#
# Evaluasi di TEST SET (10%):
# Loss: 0.2560 | Akurasi: 0.8985

# %% [markdown]
# Visualisasi akurasi tiap fold

# %%
import matplotlib.pyplot as plt

# Ambil nomor fold
folds = [f + 1 for f in fold_results.keys()]

# Ambil nilai akurasi dari key 'best_acc'
accuracies = [v['best_acc'] for v in fold_results.values()]

# (Opsional) ambil juga waktu training per fold
times = [v['fold_time'] / 60 for v in fold_results.values()]  # ubah jadi menit

# --- Buat grafik akurasi ---
plt.figure(figsize=(8,5))
plt.bar(folds, accuracies, color='skyblue', edgecolor='black')
plt.title("Akurasi per Fold (K-Fold Cross Validation)")
plt.xlabel("Fold")
plt.ylabel("Akurasi")
plt.ylim(0, 1)

# Tambahkan label nilai di atas bar
for i, acc in enumerate(accuracies):
    plt.text(folds[i], acc + 0.005, f"{acc:.4f}", ha='center', fontsize=10)

plt.show()

# --- Cetak statistik tambahan ---
print("\n=== RINGKASAN HASIL K-FOLD ===")
for f, (acc, t) in enumerate(zip(accuracies, times)):
    print(f"Fold {f+1}: Akurasi = {acc:.4f} | Waktu = {t:.2f} menit")

print(f"\nRata-rata Akurasi: {np.mean(accuracies):.4f}")
print(f"Rata-rata Waktu per Fold: {np.mean(times):.2f} menit")
# Out:
# === RINGKASAN HASIL K-FOLD ===
# Fold 1: Akurasi = 0.9287 | Waktu = 15.26 menit
# Fold 2: Akurasi = 0.9261 | Waktu = 14.72 menit
# Fold 3: Akurasi = 0.9175 | Waktu = 14.97 menit
# Fold 4: Akurasi = 0.9192 | Waktu = 15.09 menit
# Fold 5: Akurasi = 0.9175 | Waktu = 15.33 menit
#
# Rata-rata Akurasi: 0.9218
# Rata-rata Waktu per Fold: 15.07 menit
