# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import cv2
from torchvision import transforms, models
from PIL import Image
import os
import random

# %% [markdown]
# # Path setup

# %%
# Path untuk model yang sudah ditraining
MODEL_PATH = r"/kaggle/input/resnetgradcam/fold_5_best_model.pth"

# Path dataset
DATASET_PATH = r"/kaggle/input/data-val"

# Path untuk menyimpan hasil Grad-CAM
OUTPUT_DIR = r"Grad-CAM Result"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Class names
CLASS_NAMES = ['other_activities', 'safe_driving', 'talking_phone', 'texting_phone', 'turning']

# %% [markdown]
# # Fungsi gradcam

# %%
class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None
        
        # Hook untuk mendapatkan aktivasi dan gradients
        self.target_layer.register_forward_hook(self.forward_hook)
        self.target_layer.register_full_backward_hook(self.backward_hook)
    
    def forward_hook(self, module, input, output):
        self.activations = output
    
    def backward_hook(self, module, grad_input, grad_output):
        self.gradients = grad_output[0]
    
    def generate_cam(self, input_image, target_class=None):
        # Forward pass
        output = self.model(input_image)
        
        if target_class is None:
            target_class = output.argmax(dim=1).item()
        
        # Zero gradients
        self.model.zero_grad()
        
        # Backward pass untuk class target
        one_hot = torch.zeros_like(output)
        one_hot[0][target_class] = 1
        output.backward(gradient=one_hot)
        
        # Calculate weights
        gradients = self.gradients.detach().cpu().numpy()[0]
        activations = self.activations.detach().cpu().numpy()[0]
        
        weights = np.mean(gradients, axis=(1, 2))
        
        # Generate CAM
        cam = np.zeros(activations.shape[1:], dtype=np.float32)
        for i, w in enumerate(weights):
            cam += w * activations[i]
        
        # Apply ReLU
        cam = np.maximum(cam, 0)
        
        # Normalize
        cam = cam - np.min(cam)
        cam = cam / (np.max(cam) + 1e-8)
        
        return cam, output, target_class

# %% [markdown]
# # Load trained model

# %%
def load_model(model_path, num_classes=5):
    """Load trained ResNet-18 model"""
    model = models.resnet18(weights=False)
    model.fc = nn.Linear(model.fc.in_features, num_classes)

    # Load checkpoint and support multiple common formats:
    # - a plain state_dict saved via torch.save(model.state_dict(), path)
    # - a checkpoint dict with keys like 'model_state_dict' or 'state_dict'
    checkpoint = torch.load(model_path, map_location=device)

    if isinstance(checkpoint, dict):
        if 'model_state_dict' in checkpoint:
            state_dict = checkpoint['model_state_dict']
        elif 'state_dict' in checkpoint:
            state_dict = checkpoint['state_dict']
        else:
            # Fallback: assume the dict *is* the state_dict
            state_dict = checkpoint
    else:
        # checkpoint is likely an OrderedDict state_dict
        state_dict = checkpoint

    model.load_state_dict(state_dict)
    model.to(device)
    model.eval()

    return model

# %% [markdown]
# # Preprocessing

# %%
def preprocess_image(image_path):
    """Preprocess image for ResNet-18"""
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                           std=[0.229, 0.224, 0.225])
    ])
    
    image = Image.open(image_path).convert('RGB')
    original_image = np.array(image)
    input_tensor = transform(image).unsqueeze(0).to(device)
    
    return input_tensor, original_image

# %% [markdown]
# # Generate dan visualisasi grad-cam dengan 3 subplot

# %%
def visualize_gradcam_simple(image_path, model, target_layer, true_class, save_path):
    
    # Preprocess image
    input_tensor, original_image = preprocess_image(image_path)
    
    # Initialize Grad-CAM
    grad_cam = GradCAM(model, target_layer)
    
    # Generate CAM
    cam, output, predicted_class = grad_cam.generate_cam(input_tensor)
    
    # Get confidence
    probabilities = torch.softmax(output, dim=1)[0].detach().cpu().numpy()
    confidence = probabilities[predicted_class]
    
    # Resize CAM to match original image
    cam_resized = cv2.resize(cam, (original_image.shape[1], original_image.shape[0]))
    cam_resized = np.uint8(255 * cam_resized)
    heatmap = cv2.applyColorMap(cam_resized, cv2.COLORMAP_JET)
    
    # Convert original (PIL -> numpy) which is in RGB to BGR so it matches OpenCV heatmap
    original_bgr = cv2.cvtColor(original_image, cv2.COLOR_RGB2BGR)

    # Superimpose heatmap on original (both in BGR)
    superimposed_img = heatmap.astype(float) * 0.4 + original_bgr.astype(float) * 0.6
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)

    # Convert BGR results back to RGB for matplotlib
    superimposed_img_rgb = cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB)
    heatmap_rgb = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    
    # Class names
    class_names = ['other_activities', 'safe_driving', 'talking_phone', 
                   'texting_phone', 'turning']
    
    # Determine if prediction is correct
    is_correct = (predicted_class == true_class)
    result_text = "CORRECT" if is_correct else "WRONG"
    result_color = "green" if is_correct else "red"
    
    # Create figure with 3 subplots
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    axes[0].imshow(original_image)
    axes[0].set_title(f'Original\nTrue: {class_names[true_class]}', fontsize=12)
    axes[0].axis('off')
    
    # Heatmap
    axes[1].imshow(heatmap_rgb)
    axes[1].set_title('Grad-CAM Heatmap', fontsize=12)
    axes[1].axis('off')
    
    # Superimposed image dengan informasi prediksi
    axes[2].imshow(superimposed_img_rgb)
    pred_class_name = class_names[predicted_class]
    true_class_name = class_names[true_class]
    
    title = (f'Overlay\nPred: {pred_class_name}\n'
             f'True: {true_class_name}\n'
             f'Result: {result_text}\n'
             f'Conf: {confidence:.3f}')
    
    axes[2].set_title(title, color=result_color, fontsize=12)
    axes[2].axis('off')
    
    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.close('all')

    return is_correct, predicted_class, confidence

# %% [markdown]
# # Analisis prediksi sampel dan save hasil

# %%
def analyze_class_predictions_simple(model, target_layer):
    """Analisis prediksi untuk SEMUA sampel di setiap kelas dan simpan hasil"""
    
    print("Starting analysis of predictions for each class...")
    print("Processing ALL samples from each class...\n")
    
    # Dictionary untuk melacak hasil
    class_results = {class_name: {'correct': [], 'wrong': []} for class_name in CLASS_NAMES}
    
    # Iterasi melalui setiap kelas
    for class_idx, class_name in enumerate(CLASS_NAMES):
        print(f"\nAnalyzing class: {class_name}")
        
        class_path = os.path.join(DATASET_PATH, class_name)
        
        if not os.path.exists(class_path):
            print(f"  Class path not found: {class_path}")
            continue
        
        # Get all images in the class
        all_images = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
        
        if not all_images:
            print(f"  No images found in {class_path}")
            continue
        
        print(f"  Found {len(all_images)} images to process...")
        
        # Process SEMUA images (tanpa batasan)
        for idx, img_name in enumerate(all_images, 1):
            img_path = os.path.join(class_path, img_name)
            
            try:
                # Create save path
                save_filename = f"{class_name}_{img_name.split('.')[0]}_gradcam.png"
                save_path = os.path.join(OUTPUT_DIR, save_filename)
                
                # Generate dan simpan Grad-CAM
                is_correct, predicted_class, confidence = visualize_gradcam_simple(
                    image_path=img_path,
                    model=model,
                    target_layer=target_layer,
                    true_class=class_idx,
                    save_path=save_path
                )
                
                # Store results
                result_info = {
                    'image_path': img_path,
                    'predicted_class': predicted_class,
                    'confidence': confidence,
                    'save_path': save_path
                }
                
                result_type = 'correct' if is_correct else 'wrong'
                class_results[class_name][result_type].append(result_info)
                
                status = "✓" if is_correct else "✗"
                print(f"  [{idx}/{len(all_images)}] {status} {img_name} -> {CLASS_NAMES[predicted_class]} (conf: {confidence:.3f})")
                
            except Exception as e:
                print(f"  [{idx}/{len(all_images)}] Error processing {img_name}: {str(e)}")
                continue
    
    return class_results

# %% [markdown]
# # Print summary analisis

# %%
def print_analysis_summary(class_results):
    
    print("\n" + "="*60)
    print("ANALYSIS SUMMARY")
    print("="*60)
    
    total_correct = 0
    total_wrong = 0
    
    for class_name in CLASS_NAMES:
        correct_count = len(class_results[class_name]['correct'])
        wrong_count = len(class_results[class_name]['wrong'])
        total_samples = correct_count + wrong_count
        
        total_correct += correct_count
        total_wrong += wrong_count
        
        accuracy = correct_count / total_samples if total_samples > 0 else 0
        
        print(f"{class_name:20} | Correct: {correct_count:2d} | Wrong: {wrong_count:2d} | "
              f"Total: {total_samples:2d} | Accuracy: {accuracy:6.2%}")
    
    print("-"*60)
    overall_accuracy = total_correct / (total_correct + total_wrong) if (total_correct + total_wrong) > 0 else 0
    print(f"{'OVERALL':20} | Correct: {total_correct:2d} | Wrong: {total_wrong:2d} | "
          f"Total: {total_correct + total_wrong:2d} | Accuracy: {overall_accuracy:6.2%}")

# %% [markdown]
# # Main execution

# %%
if __name__ == "__main__":
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Load model
    print("Loading model...")
    try:
        model = load_model(MODEL_PATH, num_classes=5)
        print("Model loaded successfully!")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()
    
    # Get target layer
    target_layer = model.layer4[1].conv2
    
    # Analyze predictions untuk SEMUA sampel di setiap kelas
    results = analyze_class_predictions_simple(
        model=model, 
        target_layer=target_layer
    )
    
    # Print summary
    print_analysis_summary(results)
    
    print(f"\nAll Grad-CAM visualizations saved to: {OUTPUT_DIR}")
# Out:
# Using device: cuda
# Loading model...
# Model loaded successfully!
# Starting analysis of predictions for each class...
# Processing ALL samples from each class...
#
#
# Analyzing class: other_activities
#   Found 237 images to process...
#   [1/237] ✓ img_17534.jpg -> other_activities (conf: 1.000)
#   [2/237] ✓ img_20458.jpg -> other_activities (conf: 1.000)
#   [3/237] ✓ IMG_20240930_143931282_HDR_AE.jpg -> other_activities (conf: 0.997)
#   [4/237] ✓ img_23170.jpg -> other_activities (conf: 1.000)
#   [5/237] ✓ 2019-04-2417-06-34.png -> other_activities (conf: 1.000)
#   [6/237] ✓ IMG_20240930_141510006_HDR.jpg -> other_activities (conf: 0.983)
#   [7/237] ✓ img_14778.jpg -> other_activities (conf: 1.000)
#   [8/237] ✓ img_20846.jpg -> other_activities (conf: 1.000)
#   [9/237] ✓ img_17696.jpg -> other_activities (conf: 1.000)
#   [10/237] ✓ IMG_20240930_140112031_HDR_AE.jpg -> other_activities (conf: 1.000)
#   
HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [26/336] ✓ img_67639.jpg -> safe_driving (conf: 1.000)
#   [27/336] ✓ img_57235.jpg -> safe_driving (conf: 1.000)
#   [28/336] ✓ img_31094.jpg -> safe_driving (conf: 1.000)
#   [29/336] ✓ img_63859.jpg -> safe_driving (conf: 1.000)
#   [30/336] ✓ img_97519.jpg -> safe_driving (conf: 1.000)
#   [31/336] ✓ img_44388.jpg -> safe_driving (conf: 1.000)
#   [32/336] ✓ img_97329.jpg -> safe_driving (conf: 1.000)
#   [33/336] ✓ img_59936.jpg -> safe_driving (conf: 0.999)
#   [34/336] ✓ img_61593.jpg -> safe_driving (conf: 1.000)
#   [35/336] ✓ img_71091.jpg -> safe_driving (conf: 1.000)
#   [36/336] ✓ img_81350.jpg -> safe_driving (conf: 1.000)
#   [37/336] ✓ img_86427.jpg -> safe_driving (conf: 1.000)
#   [38/336] ✓ img_38621.jpg -> safe_driving (conf: 0.999)
#   [39/336] ✓ img_94048.jpg -> safe_driving (conf: 1.000)
#   [40/336] ✓ img_81340.jpg -> safe_driving (conf: 1.000)
#   [41/336] ✓ img_52653.jpg -> safe_driving (conf: 1.000)
#   [42/336] ✓ img_90102.jpg -> safe_driving (conf: 1.000)
#   [43/336] ✓ img_30330.jpg -> safe_driving (conf: 1.000)
#   [44/336] ✓ 2019-04-2417-22-09.png -> safe_driving (conf: 1.000)
#   [45/336] ✓ img_56093.jpg -> safe_driving (conf: 0.999)
#   [46/336] ✓ img_44933.jpg -> safe_driving (conf: 1.000)
#   [47/336] ✓ img_98143.jpg -> safe_driving (conf: 0.999)
#   [48/336] ✓ img_69977.jpg -> safe_driving (conf: 1.000)
#   [49/336] ✓ img_82453.jpg -> safe_driving (conf: 1.000)
#   [50/336] ✓ img_59907.jpg -> safe_driving (conf: 1.000)
#   [51/336] ✓ img_99179.jpg -> safe_driving (conf: 1.000)
#   [52/336] ✓ img_31345.jpg -> safe_driving (conf: 1.000)
#   [53/336] ✓ img_47225.jpg -> safe_driving (conf: 1.000)
#   [54/336] ✓ img_96427.jpg -> safe_driving (conf: 1.000)
#   [55/336] ✓ img_67320.jpg -> safe_driving (conf: 1.000)
#   [56/336] ✓ img_98853.jpg -> safe_driving (conf: 1.000)
#   [57/336] ✓ img_42295.jpg -> safe_driving (conf: 1.000)
#   [58/336] ✓ IMG_20240930_135704991_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [59/336] ✓ img_61067.jpg -> safe_driving (conf: 1.000)
#   [60/336] ✓ img_69183.jpg -> safe_driving (conf: 1.000)
#   [61/336] ✓ img_99527.jpg -> safe_driving (conf: 1.000)
#   [62/336] ✓ img_42975.jpg -> safe_driving (conf: 1.000)
#   [63/336] ✓ img_55100.jpg -> safe_driving (conf: 1.000)
#   [64/336] ✓ img_68412.jpg -> safe_driving (conf: 1.000)
#   [65/336] ✓ img_51985.jpg -> safe_driving (conf: 1.000)
#   [66/336] ✓ img_82122.jpg -> safe_driving (conf: 1.000)
#   [67/336] ✓ img_32313.jpg -> safe_driving (conf: 1.000)
#   [68/336] ✓ img_40038.jpg -> safe_driving (conf: 1.000)
#   [69/336] ✓ img_90333.jpg -> safe_driving (conf: 1.000)
#   [70/336] ✓ img_88177.jpg -> safe_driving (conf: 1.000)
#   [71/336] ✓ img_54333.jpg -> safe_driving (conf: 1.000)
#   [72/336] ✓ img_66407.jpg -> safe_driving (conf: 1.000)
#   [73/336] ✓ img_43317.jpg -> safe_driving (conf: 1.000)
#   [74/336] ✓ img_54966.jpg -> safe_driving (conf: 1.000)
#   [75/336] ✓ img_59561.jpg -> safe_driving (conf: 1.000)
#   [76/336] ✓ img_69997.jpg -> safe_driving (conf: 1.000)
#   [77/336] ✓ IMG_20240930_140649099_HDR.jpg -> safe_driving (conf: 1.000)
#   [78/336] ✓ img_46190.jpg -> safe_driving (conf: 1.000)
#   [79/336] ✓ img_60168.jpg -> safe_driving (conf: 1.000)
#   [80/336] ✓ img_79759.jpg -> safe_driving (conf: 1.000)
#   [81/336] ✓ img_58093.jpg -> safe_driving (conf: 1.000)
#   [82/336] ✓ img_41611.jpg -> safe_driving (conf: 1.000)
#   [83/336] ✓ img_98115.jpg -> safe_driving (conf: 1.000)
#   [84/336] ✓ img_34518.jpg -> safe_driving (conf: 0.999)
#   [85/336] ✓ img_94525.jpg -> safe_driving (conf: 1.000)
#   [86/336] ✓ img_71387.jpg -> safe_driving (conf: 1.000)
#   [87/336] ✓ img_53692.jpg -> safe_driving (conf: 1.000)
#   [88/336] ✓ img_53356.jpg -> safe_driving (conf: 1.000)
#   [89/336] ✓ img_88793.jpg -> safe_driving (conf: 1.000)
#   [90/336] ✓ 2019-04-2416-18-23.png -> safe_driving (conf: 0.999)
#   [91/336] ✓ IMG_20240930_133616144_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [92/336] ✓ img_43739.jpg -> safe_driving (conf: 0.999)
#   [93/336] ✓ img_62101.jpg -> safe_driving (conf: 1.000)
#   [94/336] ✓ img_39565.jpg -> safe_driving (conf: 0.999)
#   [95/336] ✓ img_65602.jpg -> safe_driving (conf: 1.000)
#   [96/336] ✓ img_62066.jpg -> safe_driving (conf: 1.000)
#   [97/336] ✓ img_53234.jpg -> safe_driving (conf: 1.000)
#   [98/336] ✓ img_96406.jpg -> safe_driving (conf: 1.000)
#   [99/336] ✓ img_58502.jpg -> safe_driving (conf: 1.000)
#   [100/336] ✓ img_47017.jpg -> safe_driving (conf: 1.000)
#   [101/336] ✓ img_74157.jpg -> safe_driving (conf: 0.999)
#   [102/336] ✓ img_48765.jpg -> safe_driving (conf: 0.999)
#   [103/336] ✓ img_84384.jpg -> safe_driving (conf: 1.000)
#   [104/336] ✓ img_32074.jpg -> safe_driving (conf: 1.000)
#   [105/336] ✓ img_69376.jpg -> safe_driving (conf: 0.999)
#   [106/336] ✓ img_43296.jpg -> safe_driving (conf: 1.000)
#   [107/336] ✓ img_85949.jpg -> safe_driving (conf: 0.994)
#   [108/336] ✓ img_71483.jpg -> safe_driving (conf: 1.000)
#   [109/336] ✓ img_65833.jpg -> safe_driving (conf: 1.000)
#   [110/336] ✓ img_101668.jpg -> safe_driving (conf: 1.000)
#   [111/336] ✓ IMG_20240930_140249250_HDR_AE.jpg -> safe_driving (conf: 0.998)
#   [112/336] ✓ img_68652.jpg -> safe_driving (conf: 1.000)
#   [113/336] ✓ img_74751.jpg -> safe_driving (conf: 0.999)
#   [114/336] ✓ img_77606.jpg -> safe_driving (conf: 1.000)
#   [115/336] ✓ img_28569.jpg -> safe_driving (conf: 1.000)
#   [116/336] ✓ img_46060.jpg -> safe_driving (conf: 1.000)
#   [117/336] ✓ img_92629.jpg -> safe_driving (conf: 1.000)
#   [118/336] ✓ img_66711.jpg -> safe_driving (conf: 1.000)
#   [119/336] ✓ img_62023.jpg -> safe_driving (conf: 1.000)
#   [120/336] ✓ img_44390.jpg -> safe_driving (conf: 1.000)
#   [121/336] ✓ img_80170.jpg -> safe_driving (conf: 1.000)
#   [122/336] ✓ img_84899.jpg -> safe_driving (conf: 1.000)
#   [123/336] ✓ img_93047.jpg -> safe_driving (conf: 1.000)
#   [124/336] ✓ img_84289.jpg -> safe_driving (conf: 1.000)
#   [125/336] ✓ img_72865.jpg -> safe_driving (conf: 1.000)
#   [126/336] ✓ img_37575.jpg -> safe_driving (conf: 1.000)
#   [127/336] ✓ img_66355.jpg -> safe_driving (conf: 0.994)
#   [128/336] ✓ Screenshot_107.png -> safe_driving (conf: 1.000)
#   [129/336] ✓ img_46624.jpg -> safe_driving (conf: 1.000)
#   [130/336] ✓ img_82545.jpg -> safe_driving (conf: 1.000)
#   [131/336] ✓ img_34774.jpg -> safe_driving (conf: 0.999)
#   [132/336] ✓ img_63077.jpg -> safe_driving (conf: 1.000)
#   [133/336] ✓ img_49150.jpg -> safe_driving (conf: 0.999)
#   [134/336] ✓ img_94359.jpg -> safe_driving (conf: 0.999)
#   [135/336] ✓ img_62053.jpg -> safe_driving (conf: 1.000)
#   [136/336] ✓ img_72332.jpg -> safe_driving (conf: 1.000)
#   [137/336] ✓ img_43304.jpg -> safe_driving (conf: 1.000)
#   [138/336] ✓ img_51232.jpg -> safe_driving (conf: 1.000)
#   [139/336] ✓ img_37011.jpg -> safe_driving (conf: 1.000)
#   [140/336] ✓ img_60355.jpg -> safe_driving (conf: 1.000)
#   [141/336] ✓ img_77617.jpg -> safe_driving (conf: 0.998)
#   [142/336] ✓ img_66991.jpg -> safe_driving (conf: 1.000)
#   [143/336] ✓ img_53025.jpg -> safe_driving (conf: 1.000)
#   [144/336] ✓ img_91958.jpg -> safe_driving (conf: 1.000)
#   [145/336] ✓ img_90443.jpg -> safe_driving (conf: 0.998)
#   [146/336] ✓ img_37462.jpg -> safe_driving (conf: 1.000)
#   [147/336] ✓ IMG_20240930_133206139_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [148/336] ✓ img_36370.jpg -> safe_driving (conf: 1.000)
#   [149/336] ✓ img_60944.jpg -> safe_driving (conf: 0.999)
#   [150/336] ✓ img_28167.jpg -> safe_driving (conf: 0.997)
#   [151/336] ✓ img_71265.jpg -> safe_driving (conf: 1.000)
#   [152/336] ✓ img_33353.jpg -> safe_driving (conf: 1.000)
#   [153/336] ✓ img_97751.jpg -> safe_driving (conf: 0.998)
#   [154/336] ✓ img_50749.jpg -> safe_driving (conf: 1.000)
#   [155/336] ✓ img_35327.jpg -> safe_driving (conf: 1.000)
#   [156/336] ✓ img_99515.jpg -> safe_driving (conf: 0.998)
#   [157/336] ✓ IMG_20240930_135708312_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [158/336] ✓ img_45290.jpg -> safe_driving (conf: 1.000)
#   [159/336] ✓ img_31885.jpg -> safe_driving (conf: 1.000)
#   [160/336] ✓ img_64455.jpg -> safe_driving (conf: 0.999)
#   [161/336] ✓ img_38088.jpg -> safe_driving (conf: 0.983)
#   [162/336] ✓ img_56374.jpg -> safe_driving (conf: 1.000)
#   [163/336] ✓ img_36330.jpg -> safe_driving (conf: 1.000)
#   [164/336] ✓ Screenshot_108.png -> safe_driving (conf: 0.895)
#   [165/336] ✓ img_57898.jpg -> safe_driving (conf: 1.000)
#   [166/336] ✓ img_33315.jpg -> safe_driving (conf: 1.000)
#   [167/336] ✓ img_91409.jpg -> safe_driving (conf: 1.000)
#   [168/336] ✓ img_41423.jpg -> safe_driving (conf: 1.000)
#   [169/336] ✓ img_89684.jpg -> safe_driving (conf: 1.000)
#   [170/336] ✓ img_99640.jpg -> safe_driving (conf: 0.997)
#   [171/336] ✓ img_85624.jpg -> safe_driving (conf: 1.000)
#   [172/336] ✓ IMG_20240930_133558103_HDR_AE.jpg -> safe_driving (conf: 0.998)
#   [173/336] ✓ img_32023.jpg -> safe_driving (conf: 1.000)
#   [174/336] ✓ img_37486.jpg -> safe_driving (conf: 0.998)
#   [175/336] ✓ img_57905.jpg -> safe_driving (conf: 1.000)
#   [176/336] ✓ img_31747.jpg -> safe_driving (conf: 1.000)
#   [177/336] ✓ img_29923.jpg -> safe_driving (conf: 1.000)
#   [178/336] ✓ img_90343.jpg -> safe_driving (conf: 0.999)
#   [179/336] ✓ img_91925.jpg -> safe_driving (conf: 0.999)
#   [180/336] ✓ img_101286.jpg -> safe_driving (conf: 1.000)
#   [181/336] ✓ img_100026.jpg -> safe_driving (conf: 1.000)
#   [182/336] ✓ img_44419.jpg -> safe_driving (conf: 1.000)
#   [183/336] ✓ img_36597.jpg -> safe_driving (conf: 1.000)
#   [184/336] ✓ img_68379.jpg -> safe_driving (conf: 1.000)
#   [185/336] ✓ img_73193.jpg -> safe_driving (conf: 0.998)
#   [186/336] ✓ img_34395.jpg -> safe_driving (conf: 0.999)
#   [187/336] ✓ img_60835.jpg -> safe_driving (conf: 1.000)
#   [188/336] ✓ img_73463.jpg -> safe_driving (conf: 1.000)
#   [189/336] ✓ img_46746.jpg -> safe_driving (conf: 0.984)
#   [190/336] ✓ img_53526.jpg -> safe_driving (conf: 1.000)
#   [191/336] ✓ img_86013.jpg -> safe_driving (conf: 1.000)
#   [192/336] ✓ img_39447.jpg -> safe_driving (conf: 0.999)
#   [193/336] ✓ img_54170.jpg -> safe_driving (conf: 1.000)
#   [194/336] ✓ img_80325.jpg -> safe_driving (conf: 0.999)
#   [195/336] ✓ IMG_20240930_141436920_HDR.jpg -> safe_driving (conf: 1.000)
#   [196/336] ✓ IMG_20240930_140656335_HDR.jpg -> safe_driving (conf: 0.999)
#   [197/336] ✓ img_28404.jpg -> safe_driving (conf: 1.000)
#   [198/336] ✓ img_36018.jpg -> safe_driving (conf: 1.000)
#   [199/336] ✓ IMG_20240930_132546560_HDR_AE.jpg -> safe_driving (conf: 0.987)
#   [200/336] ✓ img_58289.jpg -> safe_driving (conf: 1.000)
#   [201/336] ✓ img_34091.jpg -> safe_driving (conf: 1.000)
#   [202/336] ✓ img_62307.jpg -> safe_driving (conf: 1.000)
#   [203/336] ✓ img_67176.jpg -> safe_driving (conf: 1.000)
#   [204/336] ✓ IMG_20240930_132526267_HDR_AE.jpg -> safe_driving (conf: 0.999)
#   [205/336] ✓ img_39681.jpg -> safe_driving (conf: 1.000)
#   [206/336] ✓ img_70442.jpg -> safe_driving (conf: 0.998)
#   [207/336] ✓ img_59964.jpg -> safe_driving (conf: 1.000)
#   [208/336] ✓ img_49418.jpg -> safe_driving (conf: 0.999)
#   [209/336] ✓ img_39595.jpg -> safe_driving (conf: 1.000)
#   [210/336] ✓ img_73376.jpg -> safe_driving (conf: 0.999)
#   [211/336] ✓ IMG_20241028_143051417_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [212/336] ✓ img_70795.jpg -> safe_driving (conf: 1.000)
#   [213/336] ✓ img_53053.jpg -> safe_driving (conf: 1.000)
#   [214/336] ✓ img_69407.jpg -> safe_driving (conf: 1.000)
#   [215/336] ✓ img_81052.jpg -> safe_driving (conf: 1.000)
#   [216/336] ✓ img_63775.jpg -> safe_driving (conf: 1.000)
#   [217/336] ✓ IMG_20240930_132251106_HDR_AE.jpg -> safe_driving (conf: 0.999)
#   [218/336] ✓ img_41096.jpg -> safe_driving (conf: 1.000)
#   [219/336] ✓ img_53437.jpg -> safe_driving (conf: 1.000)
#   [220/336] ✓ img_28141.jpg -> safe_driving (conf: 1.000)
#   [221/336] ✓ img_50804.jpg -> safe_driving (conf: 1.000)
#   [222/336] ✓ img_98271.jpg -> safe_driving (conf: 1.000)
#   [223/336] ✓ img_65344.jpg -> safe_driving (conf: 1.000)
#   [224/336] ✓ 2019-04-2417-22-13.png -> safe_driving (conf: 1.000)
#   [225/336] ✓ img_52570.jpg -> safe_driving (conf: 1.000)
#   [226/336] ✓ img_61458.jpg -> safe_driving (conf: 1.000)
#   [227/336] ✓ img_41948.jpg -> safe_driving (conf: 0.999)
#   [228/336] ✓ img_34380.jpg -> safe_driving (conf: 1.000)
#   [229/336] ✓ img_38732.jpg -> safe_driving (conf: 1.000)
#   [230/336] ✓ img_47393.jpg -> safe_driving (conf: 1.000)
#   [231/336] ✓ img_89168.jpg -> safe_driving (conf: 1.000)
#   [232/336] ✓ img_54739.jpg -> safe_driving (conf: 1.000)
#   [233/336] ✓ img_69408.jpg -> safe_driving (conf: 1.000)
#   [234/336] ✓ img_58324.jpg -> safe_driving (conf: 1.000)
#   [235/336] ✓ img_42777.jpg -> safe_driving (conf: 1.000)
#   [236/336] ✓ img_55895.jpg -> safe_driving (conf: 1.000)
#   [237/336] ✓ img_76704.jpg -> safe_driving (conf: 1.000)
#   [238/336] ✓ img_86976.jpg -> safe_driving (conf: 1.000)
#   [239/336] ✓ img_50477.jpg -> safe_driving (conf: 1.000)
#   [240/336] ✓ img_48347.jpg -> safe_driving (conf: 0.999)
#   [241/336] ✓ img_61108.jpg -> safe_driving (conf: 0.999)
#   [242/336] ✓ img_92430.jpg -> safe_driving (conf: 1.000)
#   [243/336] ✓ img_92814.jpg -> safe_driving (conf: 0.999)
#   [244/336] ✓ IMG_20240930_141317303_HDR.jpg -> safe_driving (conf: 1.000)
#   [245/336] ✓ img_46229.jpg -> safe_driving (conf: 1.000)
#   [246/336] ✓ img_63414.jpg -> safe_driving (conf: 0.999)
#   [247/336] ✓ img_37109.jpg -> safe_driving (conf: 1.000)
#   [248/336] ✓ img_50417.jpg -> safe_driving (conf: 0.999)
#   [249/336] ✓ img_28066.jpg -> safe_driving (conf: 0.998)
#   [250/336] ✓ img_46034.jpg -> safe_driving (conf: 1.000)
#   [251/336] ✓ img_43775.jpg -> safe_driving (conf: 1.000)
#   [252/336] ✓ img_74460.jpg -> safe_driving (conf: 0.999)
#   [253/336] ✓ img_68539.jpg -> safe_driving (conf: 1.000)
#   [254/336] ✓ img_42143.jpg -> safe_driving (conf: 1.000)
#   [255/336] ✗ IMG_20240930_141828696_HDR.jpg -> turning (conf: 0.981)
#   [256/336] ✓ img_56672.jpg -> safe_driving (conf: 1.000)
#   [257/336] ✓ img_85798.jpg -> safe_driving (conf: 1.000)
#   [258/336] ✓ img_98899.jpg -> safe_driving (conf: 1.000)
#   [259/336] ✓ img_70040.jpg -> safe_driving (conf: 0.998)
#   [260/336] ✓ img_100145.jpg -> safe_driving (conf: 0.999)
#   [261/336] ✓ img_79799.jpg -> safe_driving (conf: 0.999)
#   [262/336] ✓ img_100824.jpg -> safe_driving (conf: 1.000)
#   [263/336] ✓ img_58791.jpg -> safe_driving (conf: 1.000)
#   [264/336] ✓ IMG_20240930_132720496_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [265/336] ✓ img_69607.jpg -> safe_driving (conf: 1.000)
#   [266/336] ✓ img_63882.jpg -> safe_driving (conf: 1.000)
#   [267/336] ✓ img_139.jpg -> safe_driving (conf: 1.000)
#   [268/336] ✓ Screenshot_103.png -> safe_driving (conf: 1.000)
#   [269/336] ✓ img_70230.jpg -> safe_driving (conf: 1.000)
#   [270/336] ✓ img_71755.jpg -> safe_driving (conf: 1.000)
#   [271/336] ✓ img_52419.jpg -> safe_driving (conf: 1.000)
#   [272/336] ✓ img_30523.jpg -> safe_driving (conf: 0.999)
#   [273/336] ✓ img_60063.jpg -> safe_driving (conf: 1.000)
#   [274/336] ✓ img_48175.jpg -> safe_driving (conf: 0.998)
#   [275/336] ✓ IMG_20240930_135909627_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [276/336] ✓ img_27832.jpg -> safe_driving (conf: 1.000)
#   [277/336] ✓ img_81530.jpg -> safe_driving (conf: 1.000)
#   [278/336] ✓ img_57969.jpg -> safe_driving (conf: 1.000)
#   [279/336] ✓ img_97738.jpg -> safe_driving (conf: 1.000)
#   [280/336] ✓ img_34095.jpg -> safe_driving (conf: 1.000)
#   [281/336] ✓ img_92507.jpg -> safe_driving (conf: 1.000)
#   [282/336] ✓ img_55934.jpg -> safe_driving (conf: 0.999)
#   [283/336] ✓ img_36173.jpg -> safe_driving (conf: 1.000)
#   [284/336] ✓ img_63590.jpg -> safe_driving (conf: 0.998)
#   [285/336] ✓ img_72193.jpg -> safe_driving (conf: 0.999)
#   [286/336] ✓ img_67865.jpg -> safe_driving (conf: 1.000)
#   [287/336] ✓ img_58456.jpg -> safe_driving (conf: 0.983)
#   [288/336] ✓ img_69859.jpg -> safe_driving (conf: 0.999)
#   [289/336] ✓ img_46441.jpg -> safe_driving (conf: 1.000)
#   [290/336] ✓ img_63389.jpg -> safe_driving (conf: 0.999)
#   [291/336] ✓ img_66375.jpg -> safe_driving (conf: 0.999)
#   [292/336] ✓ IMG_20240930_135515969_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [293/336] ✓ img_33494.jpg -> safe_driving (conf: 0.993)
#   [294/336] ✓ img_66900.jpg -> safe_driving (conf: 0.999)
#   [295/336] ✓ img_37058.jpg -> safe_driving (conf: 0.998)
#   [296/336] ✓ img_83984.jpg -> safe_driving (conf: 1.000)
#   [297/336] ✓ img_48334.jpg -> safe_driving (conf: 1.000)
#   [298/336] ✓ IMG_20240930_140315570_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [299/336] ✓ img_45276.jpg -> safe_driving (conf: 1.000)
#   [300/336] ✓ img_52830.jpg -> safe_driving (conf: 1.000)
#   [301/336] ✓ img_59778.jpg -> safe_driving (conf: 1.000)
#   [302/336] ✓ img_91788.jpg -> safe_driving (conf: 0.994)
#   [303/336] ✓ img_33475.jpg -> safe_driving (conf: 1.000)
#   [304/336] ✓ IMG_20240930_133851677_HDR_AE.jpg -> safe_driving (conf: 1.000)
#   [305/336] ✓ IMG_3750.JPG -> safe_driving (conf: 1.000)
#   [306/336] ✓ img_53535.jpg -> safe_driving (conf: 1.000)
#   [307/336] ✓ img_33028.jpg -> safe_driving (conf: 1.000)
#   [308/336] ✓ img_47385.jpg -> safe_driving (conf: 1.000)
#   [309/336] ✓ img_91381.jpg -> safe_driving (conf: 0.998)
#   [310/336] ✓ img_49623.jpg -> safe_driving (conf: 1.000)
#   [311/336] ✓ img_57075.jpg -> safe_driving (conf: 1.000)
#   [312/336] ✓ img_101175.jpg -> safe_driving (conf: 1.000)
#   [313/336] ✓ img_49589.jpg -> safe_driving (conf: 0.999)
#   [314/336] ✓ img_81643.jpg -> safe_driving (conf: 0.874)
#   [315/336] ✓ img_68866.jpg -> safe_driving (conf: 1.000)
#   [316/336] ✓ img_29332.jpg -> safe_driving (conf: 0.999)
#   [317/336] ✓ img_65491.jpg -> safe_driving (conf: 1.000)
#   [318/336] ✓ img_35845.jpg -> safe_driving (conf: 0.997)
#   [319/336] ✓ img_37626.jpg -> safe_driving (conf: 1.000)
#   [320/336] ✓ img_65222.jpg -> safe_driving (conf: 0.999)
#   [321/336] ✓ img_28882.jpg -> safe_driving (conf: 1.000)
#   [322/336] ✓ img_41276.jpg -> safe_driving (conf: 1.000)
#   [323/336] ✓ img_80630.jpg -> safe_driving (conf: 1.000)
#   [324/336] ✓ img_29357.jpg -> safe_driving (conf: 1.000)
#   [325/336] ✓ img_28760.jpg -> safe_driving (conf: 1.000)
#   [326/336] ✓ img_41663.jpg -> safe_driving (conf: 0.999)
#   [327/336] ✓ img_74002.jpg -> safe_driving (conf: 1.000)
#   [328/336] ✓ img_40457.jpg -> safe_driving (conf: 1.000)
#   [329/336] ✓ img_61788.jpg -> safe_driving (conf: 1.000)
#   [330/336] ✓ img_50384.jpg -> safe_driving (conf: 1.000)
#   [331/336] ✓ img_72495.jpg -> safe_driving (conf: 0.999)
#   [332/336] ✓ img_64413.jpg -> safe_driving (conf: 1.000)
#   [333/336] ✓ img_32486.jpg -> safe_driving (conf: 1.000)
#   [334/336] ✓ img_51347.jpg -> safe_driving (conf: 1.000)
#   [335/336] ✓ img_52100.jpg -> safe_driving (conf: 1.000)
#   [336/336] ✓ IMG_20241028_142453675_HDR_AE.jpg -> safe_driving (conf: 1.000)
#
# Analyzing class: talking_phone
#   Found 303 images to process...
#   [1/303] ✓ img_30120.jpg -> talking_phone (conf: 1.000)
#   [2/303] ✓ img_20798.jpg -> talking_phone (conf: 1.000)
#   [3/303] ✓ img_38128.jpg -> talking_phone (conf: 1.000)
#   [4/303] ✓ img_27381.jpg -> talking_phone (conf: 1.000)
#   [5/303] ✓ img_28818.jpg -> talking_phone (conf: 1.000)
#   [6/303] ✓ img_29726.jpg -> talking_phone (conf: 1.000)
#   [7/303] ✓ img_29879.jpg -> talking_phone (conf: 1.000)
#   [8/303] ✓ img_32157.jpg -> talking_phone (conf: 1.000)
#   [9/303] ✓ img_31984.jpg -> talking_phone (conf: 1.000)
#   [10/303] ✓ 2019-04-2417-17-31.png -> talking_phone (conf: 1.000)
#   [11/303] ✓ img_42555.jpg -> talking_phone (conf: 1.000)
#   [12/303] ✓ img_30679.jpg -> talking_phone (conf: 1.000)
#   [13/303] ✓ img_34625.jpg -> talking_phone (conf: 0.999)
#   [14/303] ✓ img_19561.jpg -> talking_phone (conf: 1.000)
#   [15/303] ✓ img_23352.jpg -> talking_phone (conf: 1.000)
#   [16/303] ✓ img_39720.jpg -> talking_phone (conf: 1.000)
#   [17/303] ✓ img_42753.jpg -> talking_phone (conf: 1.000)
#   [18/303] ✓ img_42321.jpg -> talking_phone (conf: 0.998)
#   [19/303] ✓ img_25350.jpg -> talking_phone (conf: 1.000)
#   [20/303] ✓ img_44242.jpg -> talking_phone (conf: 1.000)
#   [21/303] ✓ img_42748.jpg -> talking_phone (conf: 1.000)
#   [22/303] ✓ img_43975.jpg -> talking_phone (conf: 1.000)
#   [23/303] ✓ img_38746.jpg -> talking_phone (conf: 1.000)
#   [24/303] ✓ 2019-04-2416-52-43.png -> talking_phone (conf: 1.000)
